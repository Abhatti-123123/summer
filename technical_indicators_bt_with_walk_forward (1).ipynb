# %%
import sys
import yfinance as yf
import pandas as pd
import numpy as np
from itertools import product
from dateutil.relativedelta import relativedelta

# ——— 1) Core functions ———

def download_prices(ticker, start="2015-01-01"):
    df = yf.download(ticker, start=start, auto_adjust=True, progress=False)[['Close']]
    df.dropna(inplace=True)
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

def compute_rsi(close, window):
    delta    = close.diff()
    gain     = delta.clip(lower=0)
    loss     = -delta.clip(upper=0)
    avg_gain = gain.ewm(alpha=1/window, min_periods=window).mean()
    avg_loss = loss.ewm(alpha=1/window, min_periods=window).mean()
    return 100 - 100/(1 + avg_gain/avg_loss)

def compute_macd(close, fast, slow, signal_smooth):
    ema_f     = close.ewm(span=fast, adjust=False).mean()
    ema_s     = close.ewm(span=slow, adjust=False).mean()
    macd_line = ema_f - ema_s
    sig_line  = macd_line.ewm(span=signal_smooth, adjust=False).mean()
    return macd_line, sig_line

def compute_vol(close, vol_window):
    return close.pct_change().rolling(vol_window).std()

def compute_bb(close, window, num_std):
    ma = close.rolling(window).mean()
    sd = close.rolling(window).std()
    return (close - ma) / sd

def rolling_zscore(series, thr_window):
    m = series.rolling(thr_window).mean()
    s = series.rolling(thr_window).std()
    return (series - m) / s

def generate_signal(z, long_z, short_z):
    sig, state = pd.Series(0, index=z.index), 0
    prev = z.shift(1)
    for t in z.index:
        c, p = z.at[t], prev.at[t]
        if pd.notna(c) and pd.notna(p):
            if   state == 0 and c <  long_z  and p >= long_z:   state =  1
            elif state == 0 and c >  short_z and p <= short_z:  state = -1
            elif state == 1 and c >= long_z  and p <  long_z:    state =  0
            elif state == -1 and c <= short_z and p >  short_z: state =  0
        sig.at[t] = state
    return sig.astype(int)

def backtest(df, sig, fee_per_trade=0.001):
    pos    = sig.shift(1).fillna(0).astype(int)
    ret    = df['Close'].pct_change().fillna(0)
    strat  = pos * ret
    entries = (pos != pos.shift(1)) & (pos != 0)
    strat.loc[entries] -= fee_per_trade

    equity   = (1 + strat).cumprod()
    days     = len(df)
    total    = equity.iloc[-1] - 1
    cagr     = equity.iloc[-1]**(252/days) - 1
    ann_vol  = strat.std() * np.sqrt(252)
    sharpe   = (strat.mean()/strat.std()*np.sqrt(252)) if strat.std() != 0 else np.nan
    max_dd   = (equity / equity.cummax() - 1).min()
    nz       = strat[strat != 0]
    hit_rate = (nz > 0).sum() / len(nz) if len(nz) else np.nan

    # compute avg holding days
    changes = pos != pos.shift(1)
    dates   = df.index[changes]
    vals    = pos[changes]
    hold, prev, ent = [], 0, None
    for d, v in zip(dates, vals):
        if v != 0 and prev == 0:
            ent = d
        if v == 0 and prev != 0 and ent is not None:
            hold.append((d - ent).days)
            ent = None
        prev = v
    if prev != 0 and ent is not None:
        hold.append((df.index[-1] - ent).days)
    avg_hold = np.mean(hold) if hold else np.nan

    return {
        'Total Return':  total,
        'CAGR':          cagr,
        'Ann Vol':       ann_vol,
        'Sharpe':        sharpe,
        'Max Drawdown':  max_dd,
        'Trades':        int(entries.sum()),
        'Hit Rate':      hit_rate,
        'Avg Hold Days': avg_hold,
        'Data Points':   days
    }

# ——— 2) Hyperparameter grids ———

param_grids = {
    'RSI': {
        'rsi_window': [10,14,20],
        'long_z':     [-2.0,-1.5,-1.0],
        'short_z':    [ 1.0, 1.5, 2.0]
    },
    'MACD': {
        'fast':          [ 8, 12, 16],
        'slow':          [20, 26, 30],
        'signal_smooth': [ 6,  9, 12],
        'long_z':        [-2.0,-1.5,-1.0],
        'short_z':       [ 1.0, 1.5, 2.0]
    },
    'Volatility': {
        'vol_window': [10,20,30],
        'thr_window': [126,252],
        'long_z':     [-2.0,-1.5,-1.0],
        'short_z':    [ 1.0, 1.5, 2.0]
    },
    'BollingerBands': {
        'window':  [10,20,30],
        'num_std': [1.5,2.0,2.5],
        'long_z':  [-2.0,-1.5,-1.0],
        'short_z': [ 1.0, 1.5, 2.0]
    }
}

# ——— 3) Walk-forward with fix & 1-fold break ———

tickers     = ['SOXX','XLF','XLV','XLRE','GDX','GUSH','FDN']
all_results = []

for ticker in tickers:
    df = download_prices(ticker, start="2015-01-01")

    # initial 5-year training window
    train_start = df.index.min()
    train_end   = train_start + relativedelta(years=5) - pd.Timedelta(days=1)

    while True:
        # define the next 1-year test period
        test_start = train_end + pd.Timedelta(days=1)
        test_end   = test_start + relativedelta(years=1) - pd.Timedelta(days=1)
        if test_start > df.index.max():
            break

        train_df = df.loc[train_start:train_end]
        test_df  = df.loc[test_start:test_end]

        for strat, grid in param_grids.items():
            # — tune hyper-params on train_df —
            best_sh, best_p = -np.inf, None
            for vals in product(*(grid[k] for k in grid)):
                p = dict(zip(grid.keys(), vals))

                # compute train-z
                if strat == 'RSI':
                    z = rolling_zscore(compute_rsi(train_df['Close'], p['rsi_window']), thr_window=252)
                elif strat == 'MACD':
                    m, sgn = compute_macd(train_df['Close'], p['fast'], p['slow'], p['signal_smooth'])
                    z      = rolling_zscore(m - sgn, thr_window=252)
                elif strat == 'Volatility':
                    z = rolling_zscore(compute_vol(train_df['Close'], p['vol_window']), thr_window=p['thr_window'])
                else:
                    dist = compute_bb(train_df['Close'], p['window'], p['num_std'])
                    z    = rolling_zscore(dist, thr_window=252)

                sig   = generate_signal(z, p['long_z'], p['short_z'])
                stats = backtest(train_df, sig)
                if stats['Sharpe'] > best_sh:
                    best_sh, best_p = stats['Sharpe'], p.copy()

            # — compute z over full history through test_end, then slice test:
            full_hist = df.loc[:test_end]

            if strat == 'RSI':
                full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
                z_full = rolling_zscore(full_hist['RSI'], thr_window=252)
            elif strat == 'MACD':
                m_f, s_f = compute_macd(full_hist['Close'],
                                        best_p['fast'], best_p['slow'], best_p['signal_smooth'])
                z_full   = rolling_zscore(m_f - s_f, thr_window=252)
            elif strat == 'Volatility':
                full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
                z_full          = rolling_zscore(full_hist['Vol'], thr_window=best_p['thr_window'])
            else:
                dist_full = compute_bb(full_hist['Close'],
                                       window=best_p['window'],
                                       num_std=best_p['num_std'])
                z_full    = rolling_zscore(dist_full, thr_window=252)

            # slice the test-period, generate signals & backtest
            z_t   = z_full.loc[test_start:test_end]
            sig_t = generate_signal(z_t, best_p['long_z'], best_p['short_z'])
            mets  = backtest(test_df, sig_t)

            # append and print **only the first fold**, then exit
            mets.update({
                'Ticker':      ticker,
                'Strategy':    strat,
                'train_start': train_start.date(),
                'train_end':   train_end.date(),
                'test_start':  test_start.date(),
                'test_end':    test_end.date(),
                **{f"best_{k}": v for k, v in best_p.items()}
            })
            all_results.append(mets)

        # expand train window to include the test year
        train_end = test_end
# Out:
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])
# <ipython-input-12-0a2a2e5ea328>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['RSI'] = compute_rsi(full_hist['Close'], best_p['rsi_window'])
# <ipython-input-12-0a2a2e5ea328>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_hist['Vol'] = compute_vol(full_hist['Close'], best_p['vol_window'])

# %%
all_results
# Out:
# [{'Total Return': np.float64(0.3034028192394971),
#   'CAGR': np.float64(0.30203842085506905),
#   'Ann Vol': np.float64(0.16373234669081616),
#   'Sharpe': np.float64(1.6905175872209937),
#   'Max Drawdown': -0.046160803816129414,
#   'Trades': 6,
#   'Hit Rate': np.float64(0.7),
#   'Avg Hold Days': np.float64(2.3333333333333335),
#   'Data Points': 253,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.04182854291560756),
#   'CAGR': np.float64(-0.04166670604696465),
#   'Ann Vol': np.float64(0.34451934158645386),
#   'Sharpe': np.float64(0.051519847099190275),
#   'Max Drawdown': -0.27413921377123907,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.6046511627906976),
#   'Avg Hold Days': np.float64(8.285714285714286),
#   'Data Points': 253,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_fast': 16,
#   'best_slow': 30,
#   'best_signal_smooth': 9,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.09359790608652574),
#   'CAGR': np.float64(-0.09324576583697575),
#   'Ann Vol': np.float64(0.35569599555385506),
#   'Sharpe': np.float64(-0.09843623193493534),
#   'Max Drawdown': -0.2735871359039561,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5135135135135135),
#   'Avg Hold Days': np.float64(17.333333333333332),
#   'Data Points': 253,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 252,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.16357934068504876),
#   'CAGR': np.float64(0.16288277729083744),
#   'Ann Vol': np.float64(0.20322829736189787),
#   'Sharpe': np.float64(0.8432160916159991),
#   'Max Drawdown': -0.11064094087782161,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.7272727272727273),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 253,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.08466223272730589),
#   'CAGR': np.float64(0.08466223272730589),
#   'Ann Vol': np.float64(0.10211812676829292),
#   'Sharpe': np.float64(0.8461493437345331),
#   'Max Drawdown': -0.0407384882231997,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.5789473684210527),
#   'Avg Hold Days': np.float64(3.875),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.004889286719800046),
#   'CAGR': np.float64(0.004889286719800046),
#   'Ann Vol': np.float64(0.15587725337412392),
#   'Sharpe': np.float64(0.10880341393498574),
#   'Max Drawdown': -0.08366766436613227,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.5227272727272727),
#   'Avg Hold Days': np.float64(7.333333333333333),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_fast': 16,
#   'best_slow': 30,
#   'best_signal_smooth': 6,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.09426459847633106),
#   'CAGR': np.float64(-0.09426459847633106),
#   'Ann Vol': np.float64(0.20291544889382138),
#   'Sharpe': np.float64(-0.38648184806305635),
#   'Max Drawdown': -0.19673899554099517,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.5196078431372549),
#   'Avg Hold Days': np.float64(29.8),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.059117684967790685),
#   'CAGR': np.float64(-0.059117684967790685),
#   'Ann Vol': np.float64(0.11948722512388203),
#   'Sharpe': np.float64(-0.45020885693350887),
#   'Max Drawdown': -0.08424125671628635,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.43478260869565216),
#   'Avg Hold Days': np.float64(3.3),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.03669885515958038),
#   'CAGR': np.float64(0.03684772707617401),
#   'Ann Vol': np.float64(0.09482805585100855),
#   'Sharpe': np.float64(0.4285842376660965),
#   'Max Drawdown': -0.07203753327880269,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.625),
#   'Avg Hold Days': np.float64(6.0),
#   'Data Points': 251,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.022829786169678234),
#   'CAGR': np.float64(0.022921776062738264),
#   'Ann Vol': np.float64(0.18583766949058325),
#   'Sharpe': np.float64(0.2146603059400387),
#   'Max Drawdown': -0.12759191345766496,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.5245901639344263),
#   'Avg Hold Days': np.float64(8.9),
#   'Data Points': 251,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_fast': 16,
#   'best_slow': 20,
#   'best_signal_smooth': 9,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.06493701554812104),
#   'CAGR': np.float64(0.06520398610607914),
#   'Ann Vol': np.float64(0.23087398292982847),
#   'Sharpe': np.float64(0.3887043034888737),
#   'Max Drawdown': -0.19750782142023793,
#   'Trades': 13,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(8.23076923076923),
#   'Data Points': 251,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.01272266304087577),
#   'CAGR': np.float64(-0.012773025838096919),
#   'Ann Vol': np.float64(0.09739483153604678),
#   'Sharpe': np.float64(-0.08353763059781517),
#   'Max Drawdown': -0.05959483689044909,
#   'Trades': 6,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(3.6666666666666665),
#   'Data Points': 251,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.03849251163018086),
#   'CAGR': np.float64(0.038806351215888046),
#   'Ann Vol': np.float64(0.06383640252560065),
#   'Sharpe': np.float64(0.6281928267056281),
#   'Max Drawdown': -0.03482760382939465,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.5882352941176471),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 250,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.14186150391102204),
#   'CAGR': np.float64(0.14307398039830366),
#   'Ann Vol': np.float64(0.09980080080486568),
#   'Sharpe': np.float64(1.3895441055317828),
#   'Max Drawdown': -0.046246119452516665,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.5945945945945946),
#   'Avg Hold Days': np.float64(5.777777777777778),
#   'Data Points': 250,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_fast': 12,
#   'best_slow': 26,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.17331993843668037),
#   'CAGR': np.float64(0.1748212202603887),
#   'Ann Vol': np.float64(0.1893162937025105),
#   'Sharpe': np.float64(0.944553406009085),
#   'Max Drawdown': -0.09820742507925473,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.4659090909090909),
#   'Avg Hold Days': np.float64(13.444444444444445),
#   'Data Points': 250,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(-0.008712963957205111),
#   'CAGR': np.float64(-0.00878236069087035),
#   'Ann Vol': np.float64(0.02107302403883487),
#   'Sharpe': np.float64(-0.40798516684716785),
#   'Max Drawdown': -0.019423417443017565,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.6666666666666666),
#   'Avg Hold Days': np.float64(1.0),
#   'Data Points': 250,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_window': 10,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.1908684371148086),
#   'CAGR': np.float64(0.1908684371148086),
#   'Ann Vol': np.float64(0.1283757585932172),
#   'Sharpe': np.float64(1.4236700057554403),
#   'Max Drawdown': -0.057862596574880576,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.7222222222222222),
#   'Avg Hold Days': np.float64(2.4),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.13749856421255702),
#   'CAGR': np.float64(0.13749856421255702),
#   'Ann Vol': np.float64(0.20593568507274881),
#   'Sharpe': np.float64(0.7282984395019555),
#   'Max Drawdown': -0.19066777577539296,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.5806451612903226),
#   'Avg Hold Days': np.float64(8.8),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_fast': 12,
#   'best_slow': 26,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.022985918478436895),
#   'CAGR': np.float64(-0.022985918478436895),
#   'Ann Vol': np.float64(0.25622012778421094),
#   'Sharpe': np.float64(0.036596975738634206),
#   'Max Drawdown': -0.1765141444460473,
#   'Trades': 14,
#   'Hit Rate': np.float64(0.49019607843137253),
#   'Avg Hold Days': np.float64(10.428571428571429),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.02497845758481998),
#   'CAGR': np.float64(0.02497845758481998),
#   'Ann Vol': np.float64(0.014782744890723202),
#   'Sharpe': np.float64(1.6763407833770814),
#   'Max Drawdown': 0.0,
#   'Trades': 4,
#   'Hit Rate': np.float64(1.0),
#   'Avg Hold Days': np.float64(2.0),
#   'Data Points': 252,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_window': 10,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.14545530350770308),
#   'CAGR': np.float64(0.43366372321682745),
#   'Ann Vol': np.float64(0.3481393605807759),
#   'Sharpe': np.float64(1.194928279882449),
#   'Max Drawdown': -0.09196622586426739,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.6842105263157895),
#   'Avg Hold Days': np.float64(3.375),
#   'Data Points': 95,
#   'Ticker': 'SOXX',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.036710319961019366),
#   'CAGR': np.float64(-0.09444869624777608),
#   'Ann Vol': np.float64(0.39684970141621523),
#   'Sharpe': np.float64(-0.06337737947450445),
#   'Max Drawdown': -0.12509865848833357,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.5769230769230769),
#   'Avg Hold Days': np.float64(7.0),
#   'Data Points': 95,
#   'Ticker': 'SOXX',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_fast': 12,
#   'best_slow': 26,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.252788370522407),
#   'CAGR': np.float64(-0.5383715603099056),
#   'Ann Vol': np.float64(0.41311740140168746),
#   'Sharpe': np.float64(-1.649129565354642),
#   'Max Drawdown': -0.3192490617601783,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.41379310344827586),
#   'Avg Hold Days': np.float64(42.0),
#   'Data Points': 95,
#   'Ticker': 'SOXX',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.0),
#   'CAGR': np.float64(0.0),
#   'Ann Vol': np.float64(0.0),
#   'Sharpe': nan,
#   'Max Drawdown': 0.0,
#   'Trades': 0,
#   'Hit Rate': nan,
#   'Avg Hold Days': nan,
#   'Data Points': 95,
#   'Ticker': 'SOXX',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_window': 10,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.0688549020937873),
#   'CAGR': np.float64(-0.06859230364017865),
#   'Ann Vol': np.float64(0.22797671960919552),
#   'Sharpe': np.float64(-0.19738909841046093),
#   'Max Drawdown': -0.18582824040378876,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.45454545454545453),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 253,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.25269518051896234),
#   'CAGR': np.float64(-0.2518343034982241),
#   'Ann Vol': np.float64(0.353403390435393),
#   'Sharpe': np.float64(-0.6421847515085239),
#   'Max Drawdown': -0.3654541013104118,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.4594594594594595),
#   'Avg Hold Days': np.float64(7.428571428571429),
#   'Data Points': 253,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_fast': 8,
#   'best_slow': 20,
#   'best_signal_smooth': 6,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.10266863730134523),
#   'CAGR': np.float64(0.1022427613906296),
#   'Ann Vol': np.float64(0.3619264778222975),
#   'Sharpe': np.float64(0.44928150388219457),
#   'Max Drawdown': -0.27213002843940526,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5116279069767442),
#   'Avg Hold Days': np.float64(21.0),
#   'Data Points': 253,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 252,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.023105488226217608),
#   'CAGR': np.float64(0.023013119322683906),
#   'Ann Vol': np.float64(0.20258907012227184),
#   'Sharpe': np.float64(0.21183370053838416),
#   'Max Drawdown': -0.13678975990824538,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(3.25),
#   'Data Points': 253,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.11720635505623611),
#   'CAGR': np.float64(0.11720635505623611),
#   'Ann Vol': np.float64(0.06846023670552734),
#   'Sharpe': np.float64(1.6530384365194712),
#   'Max Drawdown': -0.02509936350858233,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.5882352941176471),
#   'Avg Hold Days': np.float64(2.888888888888889),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.14250169347726915),
#   'CAGR': np.float64(0.14250169347726915),
#   'Ann Vol': np.float64(0.09632293758709165),
#   'Sharpe': np.float64(1.431294262611809),
#   'Max Drawdown': -0.062033725925837,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.6),
#   'Avg Hold Days': np.float64(6.7),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_fast': 12,
#   'best_slow': 30,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.08785716383423892),
#   'CAGR': np.float64(-0.08785716383423892),
#   'Ann Vol': np.float64(0.09987543990528515),
#   'Sharpe': np.float64(-0.8705750246898636),
#   'Max Drawdown': -0.15900167985036295,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.47435897435897434),
#   'Avg Hold Days': np.float64(14.25),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.09120904887145143),
#   'CAGR': np.float64(0.09120904887145143),
#   'Ann Vol': np.float64(0.07179361527462134),
#   'Sharpe': np.float64(1.251542898979661),
#   'Max Drawdown': -0.03951790423224277,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.7058823529411765),
#   'Avg Hold Days': np.float64(2.875),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.14667199222142124),
#   'CAGR': np.float64(0.14729741338534463),
#   'Ann Vol': np.float64(0.06592649041473049),
#   'Sharpe': np.float64(2.117171222914089),
#   'Max Drawdown': -0.023626963458557526,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.6666666666666666),
#   'Avg Hold Days': np.float64(2.888888888888889),
#   'Data Points': 251,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.1657710675443247),
#   'CAGR': np.float64(0.16648367229480776),
#   'Ann Vol': np.float64(0.15513030007141587),
#   'Sharpe': np.float64(1.0699996057940664),
#   'Max Drawdown': -0.08797976769225024,
#   'Trades': 15,
#   'Hit Rate': np.float64(0.4857142857142857),
#   'Avg Hold Days': np.float64(9.8),
#   'Data Points': 251,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_fast': 12,
#   'best_slow': 30,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.18157231533998475),
#   'CAGR': np.float64(-0.1822253954660198),
#   'Ann Vol': np.float64(0.10921981195515444),
#   'Sharpe': np.float64(-1.7864028310046007),
#   'Max Drawdown': -0.2291031750646768,
#   'Trades': 6,
#   'Hit Rate': np.float64(0.4074074074074074),
#   'Avg Hold Days': np.float64(12.5),
#   'Data Points': 251,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.05870726192872566),
#   'CAGR': np.float64(0.058947917829101915),
#   'Ann Vol': np.float64(0.04525516750242946),
#   'Sharpe': np.float64(1.2878401165808764),
#   'Max Drawdown': -0.006854602178597902,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.6),
#   'Avg Hold Days': np.float64(1.25),
#   'Data Points': 251,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.022674907877833106),
#   'CAGR': np.float64(-0.022854218360829903),
#   'Ann Vol': np.float64(0.05469390803579264),
#   'Sharpe': np.float64(-0.395095341329517),
#   'Max Drawdown': -0.057907567041306285,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.6),
#   'Avg Hold Days': np.float64(3.2),
#   'Data Points': 250,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.07133652666289814),
#   'CAGR': np.float64(-0.07188619846448308),
#   'Ann Vol': np.float64(0.08129777465988045),
#   'Sharpe': np.float64(-0.8765951893189253),
#   'Max Drawdown': -0.0772676763638005,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.3939393939393939),
#   'Avg Hold Days': np.float64(10.4),
#   'Data Points': 250,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_fast': 12,
#   'best_slow': 30,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.02594810713686746),
#   'CAGR': np.float64(-0.026152953632279097),
#   'Ann Vol': np.float64(0.03573238270842239),
#   'Sharpe': np.float64(-0.7236899521550092),
#   'Max Drawdown': -0.036567956895134146,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.3076923076923077),
#   'Avg Hold Days': np.float64(5.666666666666667),
#   'Data Points': 250,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.032679880424026586),
#   'CAGR': np.float64(-0.03293696608940111),
#   'Ann Vol': np.float64(0.04900714534503189),
#   'Sharpe': np.float64(-0.6585285566917292),
#   'Max Drawdown': -0.057907567041306285,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 250,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.011528824147122085),
#   'CAGR': np.float64(-0.011528824147122085),
#   'Ann Vol': np.float64(0.034600350662665626),
#   'Sharpe': np.float64(-0.3176363717021629),
#   'Max Drawdown': -0.03093893296188599,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.75),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.13760167583765948),
#   'CAGR': np.float64(0.13760167583765948),
#   'Ann Vol': np.float64(0.09166375245617069),
#   'Sharpe': np.float64(1.451741928129604),
#   'Max Drawdown': -0.05693828846254323,
#   'Trades': 12,
#   'Hit Rate': np.float64(0.5517241379310345),
#   'Avg Hold Days': np.float64(6.916666666666667),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_fast': 12,
#   'best_slow': 30,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.04012731769859934),
#   'CAGR': np.float64(-0.04012731769859934),
#   'Ann Vol': np.float64(0.07291725356188113),
#   'Sharpe': np.float64(-0.5254602301996391),
#   'Max Drawdown': -0.12948303263689276,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.4166666666666667),
#   'Avg Hold Days': np.float64(43.0),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.021285784198624258),
#   'CAGR': np.float64(0.021285784198624258),
#   'Ann Vol': np.float64(0.0229098774730934),
#   'Sharpe': np.float64(0.9307521894362962),
#   'Max Drawdown': -0.010331547430734833,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.7777777777777778),
#   'Avg Hold Days': np.float64(2.75),
#   'Data Points': 252,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.08417229367824386),
#   'CAGR': np.float64(0.2390900542892458),
#   'Ann Vol': np.float64(0.13028858079641742),
#   'Sharpe': np.float64(1.7077886947079288),
#   'Max Drawdown': -0.013490868767905062,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(3.3333333333333335),
#   'Data Points': 95,
#   'Ticker': 'XLF',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.07510645865419718),
#   'CAGR': np.float64(0.21179502405810857),
#   'Ann Vol': np.float64(0.16180753677050574),
#   'Sharpe': np.float64(1.2656425644170723),
#   'Max Drawdown': -0.055566633103602436,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.5384615384615384),
#   'Avg Hold Days': np.float64(7.714285714285714),
#   'Data Points': 95,
#   'Ticker': 'XLF',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_fast': 16,
#   'best_slow': 30,
#   'best_signal_smooth': 12,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.046350895712833684),
#   'CAGR': np.float64(-0.11829041241736249),
#   'Ann Vol': np.float64(0.21888479204103237),
#   'Sharpe': np.float64(-0.46675221593586125),
#   'Max Drawdown': -0.15780190595344157,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.40625),
#   'Avg Hold Days': np.float64(24.0),
#   'Data Points': 95,
#   'Ticker': 'XLF',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.042922827786980866),
#   'CAGR': np.float64(0.11793432745350074),
#   'Ann Vol': np.float64(0.13885285273498738),
#   'Sharpe': np.float64(0.8692346583606854),
#   'Max Drawdown': -0.055566633103602436,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.4166666666666667),
#   'Avg Hold Days': np.float64(5.333333333333333),
#   'Data Points': 95,
#   'Ticker': 'XLF',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.0028515346273502162),
#   'CAGR': np.float64(-0.002840279760938147),
#   'Ann Vol': np.float64(0.05931497775765433),
#   'Sharpe': np.float64(-0.01873160993331007),
#   'Max Drawdown': -0.04748916958432081,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.25),
#   'Avg Hold Days': np.float64(6.0),
#   'Data Points': 253,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.05890681622051208),
#   'CAGR': np.float64(-0.0586809523562446),
#   'Ann Vol': np.float64(0.23230781470780207),
#   'Sharpe': np.float64(-0.14455739355637698),
#   'Max Drawdown': -0.17293004867309625,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.47368421052631576),
#   'Avg Hold Days': np.float64(13.25),
#   'Data Points': 253,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_fast': 12,
#   'best_slow': 20,
#   'best_signal_smooth': 12,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.09303458166081613),
#   'CAGR': np.float64(-0.09268445069092435),
#   'Ann Vol': np.float64(0.25931527798972837),
#   'Sharpe': np.float64(-0.24553306397846825),
#   'Max Drawdown': -0.2826725435777441,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.5227272727272727),
#   'Avg Hold Days': np.float64(63.0),
#   'Data Points': 253,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.007119799618207523),
#   'CAGR': np.float64(0.007091558569698009),
#   'Ann Vol': np.float64(0.22286748203027607),
#   'Sharpe': np.float64(0.14345249840991775),
#   'Max Drawdown': -0.1824805844406573,
#   'Trades': 12,
#   'Hit Rate': np.float64(0.5227272727272727),
#   'Avg Hold Days': np.float64(5.25),
#   'Data Points': 253,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.004678080048247768),
#   'CAGR': np.float64(-0.004678080048247768),
#   'Ann Vol': np.float64(0.0527111799788756),
#   'Sharpe': np.float64(-0.06270251372750997),
#   'Max Drawdown': -0.041126671283009064,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.5263157894736842),
#   'Avg Hold Days': np.float64(5.2),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.02260130935807869),
#   'CAGR': np.float64(-0.02260130935807869),
#   'Ann Vol': np.float64(0.028231493154632564),
#   'Sharpe': np.float64(-0.7956130332978065),
#   'Max Drawdown': -0.04595060552411412,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.3684210526315789),
#   'Avg Hold Days': np.float64(6.75),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_fast': 12,
#   'best_slow': 26,
#   'best_signal_smooth': 9,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.11772400372422487),
#   'CAGR': np.float64(-0.11772400372422487),
#   'Ann Vol': np.float64(0.07164191531649981),
#   'Sharpe': np.float64(-1.711956605825778),
#   'Max Drawdown': -0.1281663259498138,
#   'Trades': 12,
#   'Hit Rate': np.float64(0.4057971014492754),
#   'Avg Hold Days': np.float64(8.416666666666666),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.02513038598151196),
#   'CAGR': np.float64(0.02513038598151196),
#   'Ann Vol': np.float64(0.030728692652301173),
#   'Sharpe': np.float64(0.8229864959397314),
#   'Max Drawdown': -0.01873220173731538,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.5333333333333333),
#   'Avg Hold Days': np.float64(2.1),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.046310918021311265),
#   'CAGR': np.float64(0.046499648537480676),
#   'Ann Vol': np.float64(0.05677131955083476),
#   'Sharpe': np.float64(0.828625407471142),
#   'Max Drawdown': -0.03614547248303546,
#   'Trades': 6,
#   'Hit Rate': np.float64(0.45454545454545453),
#   'Avg Hold Days': np.float64(5.166666666666667),
#   'Data Points': 251,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.03521572611120516),
#   'CAGR': np.float64(0.035358479564632006),
#   'Ann Vol': np.float64(0.0592785349119194),
#   'Sharpe': np.float64(0.6156019214551924),
#   'Max Drawdown': -0.04967094122101612,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.4090909090909091),
#   'Avg Hold Days': np.float64(6.2),
#   'Data Points': 251,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_fast': 12,
#   'best_slow': 20,
#   'best_signal_smooth': 12,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.06393873499348945),
#   'CAGR': np.float64(-0.06418511547203931),
#   'Ann Vol': np.float64(0.12854390614541816),
#   'Sharpe': np.float64(-0.45207047944700474),
#   'Max Drawdown': -0.12095128677322664,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.45045045045045046),
#   'Avg Hold Days': np.float64(19.625),
#   'Data Points': 251,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.0020030747922521464),
#   'CAGR': np.float64(0.0020110631890692954),
#   'Ann Vol': np.float64(0.01607747958910062),
#   'Sharpe': np.float64(0.1329672566541326),
#   'Max Drawdown': -0.013692166199381739,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(1.3333333333333333),
#   'Data Points': 251,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.03273681565739006),
#   'CAGR': np.float64(-0.03299434153833347),
#   'Ann Vol': np.float64(0.0470560496051081),
#   'Sharpe': np.float64(-0.6894162690000846),
#   'Max Drawdown': -0.049444881079910186,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.4838709677419355),
#   'Avg Hold Days': np.float64(4.888888888888889),
#   'Data Points': 250,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.0036974679283430234),
#   'CAGR': np.float64(-0.003726992481694058),
#   'Ann Vol': np.float64(0.0034004641251528718),
#   'Sharpe': np.float64(-1.0963668262686292),
#   'Max Drawdown': -0.0036974679283430234,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.0),
#   'Avg Hold Days': np.float64(2.0),
#   'Data Points': 250,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_fast': 12,
#   'best_slow': 20,
#   'best_signal_smooth': 12,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.043389035653984775),
#   'CAGR': np.float64(-0.04372844594017966),
#   'Ann Vol': np.float64(0.07228469394107767),
#   'Sharpe': np.float64(-0.5825476944658384),
#   'Max Drawdown': -0.08308368094850693,
#   'Trades': 11,
#   'Hit Rate': np.float64(0.4672897196261682),
#   'Avg Hold Days': np.float64(13.818181818181818),
#   'Data Points': 250,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.00623270788281205),
#   'CAGR': np.float64(-0.00628241259238016),
#   'Ann Vol': np.float64(0.012059919051737861),
#   'Sharpe': np.float64(-0.5165278496981829),
#   'Max Drawdown': -0.012222960523574522,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(2.0),
#   'Data Points': 250,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.0534600391323341),
#   'CAGR': np.float64(-0.0534600391323341),
#   'Ann Vol': np.float64(0.047997290809117805),
#   'Sharpe': np.float64(-1.1205655995257957),
#   'Max Drawdown': -0.07997252875025906,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.42105263157894735),
#   'Avg Hold Days': np.float64(7.0),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.009530819447093553),
#   'CAGR': np.float64(0.009530819447093553),
#   'Ann Vol': np.float64(0.013146473046079596),
#   'Sharpe': np.float64(0.7280596797050111),
#   'Max Drawdown': -0.004454078330416555,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(5.333333333333333),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_fast': 12,
#   'best_slow': 20,
#   'best_signal_smooth': 12,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.044822028290259164),
#   'CAGR': np.float64(-0.044822028290259164),
#   'Ann Vol': np.float64(0.05790633298679522),
#   'Sharpe': np.float64(-0.7630627283409964),
#   'Max Drawdown': -0.09987682075538995,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.4090909090909091),
#   'Avg Hold Days': np.float64(13.857142857142858),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 252,
#   'best_long_z': -2.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.005166686905031748),
#   'CAGR': np.float64(0.005166686905031748),
#   'Ann Vol': np.float64(0.013672640603200642),
#   'Sharpe': np.float64(0.3837154656439128),
#   'Max Drawdown': -0.010632236750046542,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.4444444444444444),
#   'Avg Hold Days': np.float64(2.857142857142857),
#   'Data Points': 252,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.024692489091386438),
#   'CAGR': np.float64(0.06684369008094704),
#   'Ann Vol': np.float64(0.07420625072533767),
#   'Sharpe': np.float64(0.9078611260724152),
#   'Max Drawdown': -0.017990716231247816,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.3333333333333333),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 95,
#   'Ticker': 'XLV',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.0019950813590641214),
#   'CAGR': np.float64(-0.005283495029339891),
#   'Ann Vol': np.float64(0.10297325692923152),
#   'Sharpe': np.float64(-0.0009130927749413464),
#   'Max Drawdown': -0.042047811112325695,
#   'Trades': 2,
#   'Hit Rate': np.float64(0.46153846153846156),
#   'Avg Hold Days': np.float64(9.5),
#   'Data Points': 95,
#   'Ticker': 'XLV',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_fast': 12,
#   'best_slow': 20,
#   'best_signal_smooth': 12,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.009126234168662095),
#   'CAGR': np.float64(-0.024026339445595513),
#   'Ann Vol': np.float64(0.16400984218494463),
#   'Sharpe': np.float64(-0.06705185540871215),
#   'Max Drawdown': -0.057417554089686296,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.5098039215686274),
#   'Avg Hold Days': np.float64(24.0),
#   'Data Points': 95,
#   'Ticker': 'XLV',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 252,
#   'best_long_z': -2.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(-0.017990716231247816),
#   'CAGR': np.float64(-0.04701607607642733),
#   'Ann Vol': np.float64(0.021232892305406557),
#   'Sharpe': np.float64(-2.25725843777279),
#   'Max Drawdown': -0.017990716231247816,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.0),
#   'Avg Hold Days': np.float64(2.0),
#   'Data Points': 95,
#   'Ticker': 'XLV',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.016186771024386815),
#   'CAGR': np.float64(-0.016186771024386815),
#   'Ann Vol': np.float64(0.05680700712846202),
#   'Sharpe': np.float64(-0.25899234337154436),
#   'Max Drawdown': -0.07455401049118537,
#   'Trades': 14,
#   'Hit Rate': np.float64(0.45098039215686275),
#   'Avg Hold Days': np.float64(5.285714285714286),
#   'Data Points': 252,
#   'Ticker': 'XLRE',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 10, 8),
#   'train_end': datetime.date(2020, 10, 7),
#   'test_start': datetime.date(2020, 10, 8),
#   'test_end': datetime.date(2021, 10, 7),
#   'best_rsi_window': 10,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.01794199526705187),
#   'CAGR': np.float64(0.01794199526705187),
#   'Ann Vol': np.float64(0.04261251118490194),
#   'Sharpe': np.float64(0.4385824428885494),
#   'Max Drawdown': -0.0475677311562952,
#   'Trades': 3,
#   'Hit Rate': np.float64(0.6206896551724138),
# ...
#   'train_end': datetime.date(2024, 5, 28),
#   'test_start': datetime.date(2024, 5, 29),
#   'test_end': datetime.date(2025, 5, 28),
#   'best_window': 10,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.05939637879716031),
#   'CAGR': np.float64(0.059154799938541336),
#   'Ann Vol': np.float64(0.17258298445540574),
#   'Sharpe': np.float64(0.419908569897916),
#   'Max Drawdown': -0.12000285300820579,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.5882352941176471),
#   'Avg Hold Days': np.float64(3.25),
#   'Data Points': 253,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.1881311809693027),
#   'CAGR': np.float64(-0.18746210359609772),
#   'Ann Vol': np.float64(0.2676626501624028),
#   'Sharpe': np.float64(-0.6396717251471488),
#   'Max Drawdown': -0.25830494173767315,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.42105263157894735),
#   'Avg Hold Days': np.float64(16.0),
#   'Data Points': 253,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_fast': 16,
#   'best_slow': 30,
#   'best_signal_smooth': 9,
#   'best_long_z': -1.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.03320824790429788),
#   'CAGR': np.float64(-0.03307918534961851),
#   'Ann Vol': np.float64(0.286336563449723),
#   'Sharpe': np.float64(0.024121891399805747),
#   'Max Drawdown': -0.2811051961498533,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.4533333333333333),
#   'Avg Hold Days': np.float64(21.4),
#   'Data Points': 253,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.21585632476821037),
#   'CAGR': np.float64(0.21491740904790602),
#   'Ann Vol': np.float64(0.1080709030671787),
#   'Sharpe': np.float64(1.8537038398291608),
#   'Max Drawdown': -0.0044514720641744,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.8333333333333334),
#   'Avg Hold Days': np.float64(2.0),
#   'Data Points': 253,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2020, 1, 1),
#   'test_start': datetime.date(2020, 1, 2),
#   'test_end': datetime.date(2021, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.024797455663920775),
#   'CAGR': np.float64(0.024797455663920775),
#   'Ann Vol': np.float64(0.08755560746949569),
#   'Sharpe': np.float64(0.32333125604888474),
#   'Max Drawdown': -0.04724358288533348,
#   'Trades': 10,
#   'Hit Rate': np.float64(0.5384615384615384),
#   'Avg Hold Days': np.float64(3.9),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -2.0,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(-0.036225710563117075),
#   'CAGR': np.float64(-0.036225710563117075),
#   'Ann Vol': np.float64(0.1381697814094052),
#   'Sharpe': np.float64(-0.19795684140737108),
#   'Max Drawdown': -0.10734048523633721,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.5121951219512195),
#   'Avg Hold Days': np.float64(11.6),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_fast': 8,
#   'best_slow': 30,
#   'best_signal_smooth': 9,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.031091316463755403),
#   'CAGR': np.float64(-0.031091316463755403),
#   'Ann Vol': np.float64(0.13094304395105666),
#   'Sharpe': np.float64(-0.17606003903252224),
#   'Max Drawdown': -0.08616038991418207,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.4791666666666667),
#   'Avg Hold Days': np.float64(14.88888888888889),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.004520602656467698),
#   'CAGR': np.float64(0.004520602656467698),
#   'Ann Vol': np.float64(0.0956921367492722),
#   'Sharpe': np.float64(0.09488221671588047),
#   'Max Drawdown': -0.05185032076851148,
#   'Trades': 8,
#   'Hit Rate': np.float64(0.6086956521739131),
#   'Avg Hold Days': np.float64(4.5),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2021, 1, 1),
#   'test_start': datetime.date(2021, 1, 2),
#   'test_end': datetime.date(2022, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.09744325284434052),
#   'CAGR': np.float64(0.09784987692272629),
#   'Ann Vol': np.float64(0.13318017059730264),
#   'Sharpe': np.float64(0.767115416978869),
#   'Max Drawdown': -0.12040432222614939,
#   'Trades': 9,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(5.444444444444445),
#   'Data Points': 251,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.05309341936797929),
#   'CAGR': np.float64(0.0533104878420565),
#   'Ann Vol': np.float64(0.18854676457535788),
#   'Sharpe': np.float64(0.36921106965362427),
#   'Max Drawdown': -0.12360044162042516,
#   'Trades': 12,
#   'Hit Rate': np.float64(0.49122807017543857),
#   'Avg Hold Days': np.float64(6.75),
#   'Data Points': 251,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_fast': 8,
#   'best_slow': 30,
#   'best_signal_smooth': 9,
#   'best_long_z': -1.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.10393495756587723),
#   'CAGR': np.float64(0.10436993657302063),
#   'Ann Vol': np.float64(0.3378386110425757),
#   'Sharpe': np.float64(0.4620640409604289),
#   'Max Drawdown': -0.2051223798812808,
#   'Trades': 17,
#   'Hit Rate': np.float64(0.5333333333333333),
#   'Avg Hold Days': np.float64(13.882352941176471),
#   'Data Points': 251,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.023177199795577863),
#   'CAGR': np.float64(0.02327060541236836),
#   'Ann Vol': np.float64(0.059258286497837195),
#   'Sharpe': np.float64(0.41750109459872903),
#   'Max Drawdown': -0.048611949489263506,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(3.0),
#   'Data Points': 251,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2022, 1, 1),
#   'test_start': datetime.date(2022, 1, 2),
#   'test_end': datetime.date(2023, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.07299955154955473),
#   'CAGR': np.float64(-0.07356152333076249),
#   'Ann Vol': np.float64(0.13026490181287342),
#   'Sharpe': np.float64(-0.5211019804148481),
#   'Max Drawdown': -0.13777424152031204,
#   'Trades': 15,
#   'Hit Rate': np.float64(0.4393939393939394),
#   'Avg Hold Days': np.float64(6.266666666666667),
#   'Data Points': 250,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.09094915651460878),
#   'CAGR': np.float64(0.09170914154231813),
#   'Ann Vol': np.float64(0.10094102693562094),
#   'Sharpe': np.float64(0.9196065466940189),
#   'Max Drawdown': -0.08754939719776444,
#   'Trades': 15,
#   'Hit Rate': np.float64(0.5625),
#   'Avg Hold Days': np.float64(5.933333333333334),
#   'Data Points': 250,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_fast': 16,
#   'best_slow': 26,
#   'best_signal_smooth': 6,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.08339768690017979),
#   'CAGR': np.float64(0.08409216891290994),
#   'Ann Vol': np.float64(0.16161055366079838),
#   'Sharpe': np.float64(0.5802052259485909),
#   'Max Drawdown': -0.1589631055660785,
#   'Trades': 15,
#   'Hit Rate': np.float64(0.5147058823529411),
#   'Avg Hold Days': np.float64(12.333333333333334),
#   'Data Points': 250,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(-0.026696802675066578),
#   'CAGR': np.float64(-0.026907477701458737),
#   'Ann Vol': np.float64(0.08745663070950362),
#   'Sharpe': np.float64(-0.26733213633807673),
#   'Max Drawdown': -0.07955588841682515,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.6666666666666666),
#   'Avg Hold Days': np.float64(3.142857142857143),
#   'Data Points': 250,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2023, 1, 1),
#   'test_start': datetime.date(2023, 1, 2),
#   'test_end': datetime.date(2024, 1, 1),
#   'best_window': 30,
#   'best_num_std': 1.5,
#   'best_long_z': -2.0,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.024625185517114234),
#   'CAGR': np.float64(0.024625185517114234),
#   'Ann Vol': np.float64(0.05412014360877252),
#   'Sharpe': np.float64(0.4764542803853892),
#   'Max Drawdown': -0.027138634847656884,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.5882352941176471),
#   'Avg Hold Days': np.float64(5.0),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.0958257654984962),
#   'CAGR': np.float64(0.0958257654984962),
#   'Ann Vol': np.float64(0.10150776882209094),
#   'Sharpe': np.float64(0.952168818082524),
#   'Max Drawdown': -0.047645904818729656,
#   'Trades': 14,
#   'Hit Rate': np.float64(0.5476190476190477),
#   'Avg Hold Days': np.float64(9.071428571428571),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_fast': 16,
#   'best_slow': 26,
#   'best_signal_smooth': 6,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(-0.1335039687792825),
#   'CAGR': np.float64(-0.1335039687792825),
#   'Ann Vol': np.float64(0.10167151060201228),
#   'Sharpe': np.float64(-1.3581427599452576),
#   'Max Drawdown': -0.17139612117487635,
#   'Trades': 12,
#   'Hit Rate': np.float64(0.43661971830985913),
#   'Avg Hold Days': np.float64(8.416666666666666),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_vol_window': 20,
#   'best_thr_window': 126,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(0.006698789578043485),
#   'CAGR': np.float64(0.006698789578043485),
#   'Ann Vol': np.float64(0.05922869741382183),
#   'Sharpe': np.float64(0.14223605406747342),
#   'Max Drawdown': -0.027138634847656884,
#   'Trades': 7,
#   'Hit Rate': np.float64(0.5238095238095238),
#   'Avg Hold Days': np.float64(4.285714285714286),
#   'Data Points': 252,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2024, 1, 1),
#   'test_start': datetime.date(2024, 1, 2),
#   'test_end': datetime.date(2025, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(0.010137109936117605),
#   'CAGR': np.float64(0.027115757218744374),
#   'Ann Vol': np.float64(0.23526912150219578),
#   'Sharpe': np.float64(0.2267237880644915),
#   'Max Drawdown': -0.08844173125012988,
#   'Trades': 4,
#   'Hit Rate': np.float64(0.5),
#   'Avg Hold Days': np.float64(7.0),
#   'Data Points': 95,
#   'Ticker': 'FDN',
#   'Strategy': 'RSI',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_rsi_window': 14,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0},
#  {'Total Return': np.float64(-0.11557966922431062),
#   'CAGR': np.float64(-0.2780531439935988),
#   'Ann Vol': np.float64(0.2651301079255473),
#   'Sharpe': np.float64(-1.100050080551516),
#   'Max Drawdown': -0.14931017008556613,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.4528301886792453),
#   'Avg Hold Days': np.float64(14.4),
#   'Data Points': 95,
#   'Ticker': 'FDN',
#   'Strategy': 'MACD',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_fast': 16,
#   'best_slow': 26,
#   'best_signal_smooth': 6,
#   'best_long_z': -1.0,
#   'best_short_z': 1.0},
#  {'Total Return': np.float64(-0.13917216800346455),
#   'CAGR': np.float64(-0.32801911075793977),
#   'Ann Vol': np.float64(0.29599069183080823),
#   'Sharpe': np.float64(-1.1926102231654518),
#   'Max Drawdown': -0.2253201039002981,
#   'Trades': 1,
#   'Hit Rate': np.float64(0.44),
#   'Avg Hold Days': np.float64(70.0),
#   'Data Points': 95,
#   'Ticker': 'FDN',
#   'Strategy': 'Volatility',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_vol_window': 30,
#   'best_thr_window': 252,
#   'best_long_z': -1.5,
#   'best_short_z': 1.5},
#  {'Total Return': np.float64(0.0018735533252336456),
#   'CAGR': np.float64(0.00497754390255567),
#   'Ann Vol': np.float64(0.22140887692689357),
#   'Sharpe': np.float64(0.12830861206239774),
#   'Max Drawdown': -0.09589885096570039,
#   'Trades': 5,
#   'Hit Rate': np.float64(0.47058823529411764),
#   'Avg Hold Days': np.float64(4.6),
#   'Data Points': 95,
#   'Ticker': 'FDN',
#   'Strategy': 'BollingerBands',
#   'train_start': datetime.date(2015, 1, 2),
#   'train_end': datetime.date(2025, 1, 1),
#   'test_start': datetime.date(2025, 1, 2),
#   'test_end': datetime.date(2026, 1, 1),
#   'best_window': 20,
#   'best_num_std': 1.5,
#   'best_long_z': -1.5,
#   'best_short_z': 2.0}]

# %%
df_results = pd.DataFrame(all_results)

# %%
df_results.head()
# Out:
#    Total Return      CAGR   Ann Vol    Sharpe  Max Drawdown  Trades  Hit Rate  \
# 0      0.303403  0.302038  0.163732  1.690518     -0.046161       6  0.700000
# 1     -0.041829 -0.041667  0.344519  0.051520     -0.274139       7  0.604651
# 2     -0.093598 -0.093246  0.355696 -0.098436     -0.273587       3  0.513514
# 3      0.163579  0.162883  0.203228  0.843216     -0.110641       5  0.727273
# 4      0.084662  0.084662  0.102118  0.846149     -0.040738       8  0.578947
#
#    Avg Hold Days  Data Points Ticker  ... best_rsi_window best_long_z  \
# 0       2.333333          253   SOXX  ...            14.0        -2.0
# 1       8.285714          253   SOXX  ...             NaN        -1.5
# 2      17.333333          253   SOXX  ...             NaN        -1.5
# 3       3.000000          253   SOXX  ...             NaN        -2.0
# 4       3.875000          252   SOXX  ...            14.0        -2.0
#
#   best_short_z best_fast best_slow  best_signal_smooth  best_vol_window  \
# 0          2.0       NaN       NaN                 NaN              NaN
# 1          1.5      16.0      30.0                 9.0              NaN
# 2          2.0       NaN       NaN                 NaN             20.0
# 3          2.0       NaN       NaN                 NaN              NaN
# 4          2.0       NaN       NaN                 NaN              NaN
#
#    best_thr_window  best_window  best_num_std
# 0              NaN          NaN           NaN
# 1              NaN          NaN           NaN
# 2            252.0          NaN           NaN
# 3              NaN         30.0           1.5
# 4              NaN          NaN           NaN
#
# [5 rows x 25 columns]

# %%
agg = (
    df_results
      .groupby(['Ticker','Strategy'])
      .agg({
          'Total Return':  'mean',
          'CAGR':          'mean',
          'Ann Vol':       'mean',
          'Sharpe':        'mean',
          'Max Drawdown':  'mean',
          'Trades':        'sum',    # total across folds
          'Hit Rate':      'mean',
          'Avg Hold Days': 'mean'
      })
      .round(4)
      .reset_index()
)

print("\n=== Final Aggregated Metrics ===")
print(agg)
# Out:
# === Final Aggregated Metrics ===
#    Ticker        Strategy  Total Return    CAGR  Ann Vol  Sharpe  \
# 0     FDN  BollingerBands        0.0376  0.0379   0.1052  0.3949
# 1     FDN            MACD       -0.0167 -0.0435   0.1770  0.0506
# 2     FDN             RSI        0.0239  0.0267   0.1355  0.2821
# 3     FDN      Volatility       -0.0249 -0.0562   0.2191 -0.2767
# 4     GDX  BollingerBands        0.0462  0.0451   0.1237  0.2862
# 5     GDX            MACD        0.0256  0.0681   0.2298  0.2759
# 6     GDX             RSI        0.0763  0.0755   0.1581  0.4196
# 7     GDX      Volatility       -0.1139 -0.1276   0.2200 -0.5258
# 8    GUSH  BollingerBands       -0.1568 -0.1591   0.2528 -0.5397
# 9    GUSH            MACD        0.0423  0.0417   0.2407  0.5028
# 10   GUSH             RSI       -0.1646 -0.1637   0.3357 -0.0209
# 11   GUSH      Volatility       -0.1752 -0.1758   0.3368 -0.4851
# 12   SOXX  BollingerBands        0.0180  0.0179   0.0760  0.3156
# 13   SOXX            MACD        0.0381  0.0287   0.2315  0.4049
# 14   SOXX             RSI        0.1333  0.1811   0.1502  1.0353
# 15   SOXX      Volatility       -0.0376 -0.0848   0.2747 -0.1274
# 16    XLF  BollingerBands        0.0341  0.0466   0.0884  0.6488
# 17    XLF            MACD        0.0328  0.0558   0.1566  0.6166
# 18    XLF             RSI        0.0408  0.0668   0.0970  0.7613
# 19    XLF      Volatility       -0.0465 -0.0587   0.1498 -0.6539
# 20   XLRE  BollingerBands       -0.0087 -0.0056   0.0529 -0.0124
# 21   XLRE            MACD       -0.0297 -0.0230   0.0850 -0.2529
# 22   XLRE             RSI       -0.0170 -0.0183   0.0706 -0.1585
# 23   XLRE      Volatility       -0.0077 -0.0247   0.1062 -0.3890
# 24    XLV  BollingerBands        0.0025 -0.0023   0.0528 -0.2151
# 25    XLV            MACD       -0.0071 -0.0076   0.0732 -0.1156
# 26    XLV             RSI       -0.0038  0.0032   0.0563 -0.0258
# 27    XLV      Volatility       -0.0620 -0.0645   0.1256 -0.6370
#
#     Max Drawdown  Trades  Hit Rate  Avg Hold Days
# 0        -0.0513      36    0.6005         3.5881
# 1        -0.1290      56    0.4979        10.6258
# 2        -0.0902      51    0.5257         5.1435
# 3        -0.1880      59    0.4762        23.4869
# 4        -0.0844      73    0.5390         3.1703
# 5        -0.1777      85    0.5318         7.0574
# 6        -0.1149      53    0.5345         5.6759
# 7        -0.2231      74    0.4728         7.1728
# 8        -0.2819      61    0.4987         2.0640
# 9        -0.1830      44    0.5606         5.6493
# 10       -0.3112      52    0.5932         4.6659
# 11       -0.3350      32    0.4724        10.1870
# 12       -0.0457      28    0.6657         2.5933
# 13       -0.1412      50    0.5674         7.6828
# 14       -0.0573      43    0.6498         3.4972
# 15       -0.2103      45    0.4838        20.2062
# 16       -0.0512      29    0.5834         3.0764
# 17       -0.1175      56    0.5049         8.1599
# 18       -0.0561      33    0.5932         3.0519
# 19       -0.1640      24    0.4207        20.0694
# 20       -0.0439      32    0.4505         2.7019
# 21       -0.0908      29    0.5506        10.5849
# 22       -0.0689      40    0.4706         4.6321
# 23       -0.1142      55    0.4471         8.8100
# 24       -0.0426      36    0.4168         2.5901
# 25       -0.0531      19    0.3688         7.1722
# 26       -0.0454      35    0.4115         5.2093
# 27       -0.1287      42    0.4609        23.7862

# %%
agg
# Out:
#    Ticker        Strategy  Total Return    CAGR  Ann Vol  Sharpe  \
# 0     FDN  BollingerBands        0.0376  0.0379   0.1052  0.3949
# 1     FDN            MACD       -0.0167 -0.0435   0.1770  0.0506
# 2     FDN             RSI        0.0239  0.0267   0.1355  0.2821
# 3     FDN      Volatility       -0.0249 -0.0562   0.2191 -0.2767
# 4     GDX  BollingerBands        0.0462  0.0451   0.1237  0.2862
# 5     GDX            MACD        0.0256  0.0681   0.2298  0.2759
# 6     GDX             RSI        0.0763  0.0755   0.1581  0.4196
# 7     GDX      Volatility       -0.1139 -0.1276   0.2200 -0.5258
# 8    GUSH  BollingerBands       -0.1568 -0.1591   0.2528 -0.5397
# 9    GUSH            MACD        0.0423  0.0417   0.2407  0.5028
# 10   GUSH             RSI       -0.1646 -0.1637   0.3357 -0.0209
# 11   GUSH      Volatility       -0.1752 -0.1758   0.3368 -0.4851
# 12   SOXX  BollingerBands        0.0180  0.0179   0.0760  0.3156
# 13   SOXX            MACD        0.0381  0.0287   0.2315  0.4049
# 14   SOXX             RSI        0.1333  0.1811   0.1502  1.0353
# 15   SOXX      Volatility       -0.0376 -0.0848   0.2747 -0.1274
# 16    XLF  BollingerBands        0.0341  0.0466   0.0884  0.6488
# 17    XLF            MACD        0.0328  0.0558   0.1566  0.6166
# 18    XLF             RSI        0.0408  0.0668   0.0970  0.7613
# 19    XLF      Volatility       -0.0465 -0.0587   0.1498 -0.6539
# 20   XLRE  BollingerBands       -0.0087 -0.0056   0.0529 -0.0124
# 21   XLRE            MACD       -0.0297 -0.0230   0.0850 -0.2529
# 22   XLRE             RSI       -0.0170 -0.0183   0.0706 -0.1585
# 23   XLRE      Volatility       -0.0077 -0.0247   0.1062 -0.3890
# 24    XLV  BollingerBands        0.0025 -0.0023   0.0528 -0.2151
# 25    XLV            MACD       -0.0071 -0.0076   0.0732 -0.1156
# 26    XLV             RSI       -0.0038  0.0032   0.0563 -0.0258
# 27    XLV      Volatility       -0.0620 -0.0645   0.1256 -0.6370
#
#     Max Drawdown  Trades  Hit Rate  Avg Hold Days
# 0        -0.0513      36    0.6005         3.5881
# 1        -0.1290      56    0.4979        10.6258
# 2        -0.0902      51    0.5257         5.1435
# 3        -0.1880      59    0.4762        23.4869
# 4        -0.0844      73    0.5390         3.1703
# 5        -0.1777      85    0.5318         7.0574
# 6        -0.1149      53    0.5345         5.6759
# 7        -0.2231      74    0.4728         7.1728
# 8        -0.2819      61    0.4987         2.0640
# 9        -0.1830      44    0.5606         5.6493
# 10       -0.3112      52    0.5932         4.6659
# 11       -0.3350      32    0.4724        10.1870
# 12       -0.0457      28    0.6657         2.5933
# 13       -0.1412      50    0.5674         7.6828
# 14       -0.0573      43    0.6498         3.4972
# 15       -0.2103      45    0.4838        20.2062
# 16       -0.0512      29    0.5834         3.0764
# 17       -0.1175      56    0.5049         8.1599
# 18       -0.0561      33    0.5932         3.0519
# 19       -0.1640      24    0.4207        20.0694
# 20       -0.0439      32    0.4505         2.7019
# 21       -0.0908      29    0.5506        10.5849
# 22       -0.0689      40    0.4706         4.6321
# 23       -0.1142      55    0.4471         8.8100
# 24       -0.0426      36    0.4168         2.5901
# 25       -0.0531      19    0.3688         7.1722
# 26       -0.0454      35    0.4115         5.2093
# 27       -0.1287      42    0.4609        23.7862
